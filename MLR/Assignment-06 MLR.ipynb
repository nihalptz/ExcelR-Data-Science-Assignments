# %% [markdown]
# Multiple Linear Regression

# %% [markdown]
# 1.Performing EDA for given dataset

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error,mean_absolute_error,classification_report
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso, Ridge

# %%
data=pd.read_csv("ToyotaCorolla - MLR.csv")
data
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1436 rows x 11 columns]

# %%
data.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# min     1300.00000     2.000000        4.0     3.000000  1000.00000
# 25%     1400.00000     3.000000        4.0     5.000000  1040.00000
# 50%     1600.00000     4.000000        4.0     5.000000  1070.00000
# 75%     1600.00000     5.000000        4.0     5.000000  1085.00000
# max    16000.00000     5.000000        4.0     6.000000  1615.00000

# %%
data.shape
# Out:
# (1436, 11)

# %%
data.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
data[data.duplicated()]
# Out:
#      Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 113  24950          8  13253    Diesel  116          0  2000      5
#
#      Cylinders  Gears  Weight
# 113          4      5    1320

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Price, Age_08_04, KM, Fuel_Type, HP, Automatic, cc, Doors, Cylinders, Gears, Weight]
# Index: []

# %%
correlation=data.corr(numeric_only=True)
correlation
# Out:
#               Price  Age_08_04        KM        HP  Automatic        cc  \
# Price      1.000000  -0.876273 -0.569420  0.314134   0.033928  0.124375
# Age_08_04 -0.876273   1.000000  0.504575 -0.155293   0.031354 -0.096549
# KM        -0.569420   0.504575  1.000000 -0.332904  -0.082168  0.103822
# HP         0.314134  -0.155293 -0.332904  1.000000   0.013313  0.035207
# Automatic  0.033928   0.031354 -0.082168  0.013313   1.000000  0.066934
# cc         0.124375  -0.096549  0.103822  0.035207   0.066934  1.000000
# Doors      0.183604  -0.146929 -0.035193  0.091803  -0.027492  0.079254
# Cylinders       NaN        NaN       NaN       NaN        NaN       NaN
# Gears      0.063831  -0.005629  0.014890  0.209642  -0.098582  0.014732
# Weight     0.575869  -0.466484 -0.023969  0.087143   0.058499  0.335077
#
#               Doors  Cylinders     Gears    Weight
# Price      0.183604        NaN  0.063831  0.575869
# Age_08_04 -0.146929        NaN -0.005629 -0.466484
# KM        -0.035193        NaN  0.014890 -0.023969
# HP         0.091803        NaN  0.209642  0.087143
# Automatic -0.027492        NaN -0.098582  0.058499
# cc         0.079254        NaN  0.014732  0.335077
# Doors      1.000000        NaN -0.160101  0.301734
# Cylinders       NaN        NaN       NaN       NaN
# Gears     -0.160101        NaN  1.000000  0.021238
# Weight     0.301734        NaN  0.021238  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %% [markdown]
# Data Visualization

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Age_08_04'}>,
#         <Axes: title={'center': 'KM'}>],
#        [<Axes: title={'center': 'HP'}>,
#         <Axes: title={'center': 'Automatic'}>,
#         <Axes: title={'center': 'cc'}>],
#        [<Axes: title={'center': 'Doors'}>,
#         <Axes: title={'center': 'Cylinders'}>,
#         <Axes: title={'center': 'Gears'}>],
#        [<Axes: title={'center': 'Weight'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.countplot(x='Fuel_Type',data=data)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %%
data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Removing outlier

# %%
numeric_data = data.select_dtypes(include=['number'])

# Calculate Q1 and Q3
Q1 = numeric_data.quantile(0.25)
Q3 = numeric_data.quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to remove outliers
data_clean = numeric_data[~((numeric_data < lower_bound) | (numeric_data > upper_bound)).any(axis=1)]

# Display the cleaned DataFrame
print(data_clean)
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 9     12950         23  71138   69          0  1900      3          4      5
# 18    16750         24  25563  110          0  1600      3          4      5
# 19    16950         30  64359  110          0  1600      3          4      5
# 20    15950         30  67660  110          0  1600      3          4      5
# 22    15950         28  56349  110          0  1600      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
#       Weight
# 9       1105
# 18      1065
# 19      1105
# 20      1105
# 22      1120
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1098 rows x 10 columns]

# %%
numeric_data = data.select_dtypes(include=[np.number])

# Calculate Q1 (25th percentile) and Q3 (75th percentile) for each column
Q1 = numeric_data.quantile(0.25)
Q3 = numeric_data.quantile(0.75)
IQR = Q3 - Q1

# Remove outliers
filtered_data = numeric_data[~((numeric_data < (Q1 - 1.5 * IQR)) | (numeric_data > (Q3 + 1.5 * IQR))).any(axis=1)]


filtered_data = data.loc[filtered_data.index]

filtered_data
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 9     12950         23  71138    Diesel   69          0  1900      3
# 18    16750         24  25563    Petrol  110          0  1600      3
# 19    16950         30  64359    Petrol  110          0  1600      3
# 20    15950         30  67660    Petrol  110          0  1600      3
# 22    15950         28  56349    Petrol  110          0  1600      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 9             4      5    1105
# 18            4      5    1065
# 19            4      5    1105
# 20            4      5    1105
# 22            4      5    1120
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1098 rows x 11 columns]

# %%
data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Data Encoding : categorical to numerical

# %%
data.dtypes=='object'
# Out:
# Price        False
# Age_08_04    False
# KM           False
# Fuel_Type     True
# HP           False
# Automatic    False
# cc           False
# Doors        False
# Cylinders    False
# Gears        False
# Weight       False
# dtype: bool

# %%
label=LabelEncoder()
data['Fuel_Type']=label.fit_transform(data['Fuel_Type'])
data
# Out:
#       Price  Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986          1   90          0  2000      3
# 1     13750         23  72937          1   90          0  2000      3
# 2     13950         24  41711          1   90          0  2000      3
# 3     14950         26  48000          1   90          0  2000      3
# 4     13750         30  38500          1   90          0  2000      3
# ...     ...        ...    ...        ...  ...        ...   ...    ...
# 1431   7500         69  20544          2   86          0  1300      3
# 1432  10845         72  19000          2   86          0  1300      3
# 1433   8500         71  17016          2   86          0  1300      3
# 1434   7250         70  16916          2   86          0  1300      3
# 1435   6950         76      1          2  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1435 rows x 11 columns]

# %% [markdown]
# 2.Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

# %%
x=data.drop(['Price'],axis=1)
y=data['Price']
x,y
# Out:
# (      Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  Cylinders  \
#  0            23  46986          1   90          0  2000      3          4
#  1            23  72937          1   90          0  2000      3          4
#  2            24  41711          1   90          0  2000      3          4
#  3            26  48000          1   90          0  2000      3          4
#  4            30  38500          1   90          0  2000      3          4
#  ...         ...    ...        ...  ...        ...   ...    ...        ...
#  1431         69  20544          2   86          0  1300      3          4
#  1432         72  19000          2   86          0  1300      3          4
#  1433         71  17016          2   86          0  1300      3          4
#  1434         70  16916          2   86          0  1300      3          4
#  1435         76      1          2  110          0  1600      5          4
#
#        Gears  Weight
#  0         5    1165
#  1         5    1165
#  2         5    1165
#  3         5    1165
#  4         5    1170
#  ...     ...     ...
#  1431      5    1025
#  1432      5    1015
#  1433      5    1015
#  1434      5    1015
#  1435      5    1114
#
#  [1435 rows x 10 columns],
#  0       13500
#  1       13750
#  2       13950
#  3       14950
#  4       13750
#          ...
#  1431     7500
#  1432    10845
#  1433     8500
#  1434     7250
#  1435     6950
#  Name: Price, Length: 1435, dtype: int64)

# %%
data.reset_index(inplace=True)
data
# Out:
#       index  Price  Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  \
# 0         0  13500         23  46986          1   90          0  2000      3
# 1         1  13750         23  72937          1   90          0  2000      3
# 2         2  13950         24  41711          1   90          0  2000      3
# 3         3  14950         26  48000          1   90          0  2000      3
# 4         4  13750         30  38500          1   90          0  2000      3
# ...     ...    ...        ...    ...        ...  ...        ...   ...    ...
# 1430   1431   7500         69  20544          2   86          0  1300      3
# 1431   1432  10845         72  19000          2   86          0  1300      3
# 1432   1433   8500         71  17016          2   86          0  1300      3
# 1433   1434   7250         70  16916          2   86          0  1300      3
# 1434   1435   6950         76      1          2  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1430          4      5    1025
# 1431          4      5    1015
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1114
#
# [1435 rows x 12 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1148, 10), (287, 10), (1148,), (287,))

# %% [markdown]
# Standardization

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# 3.Applying MLR to training dataset

# %% [markdown]
# create model and fit it

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r_sq=model.score(x_train,y_train)
print("coefficient of determination:",r_sq)
# Out:
# coefficient of determination: 0.8694838434310366

# %%
print("Intercept:",model.intercept_)
# Out:
# Intercept: 10727.046167247385

# %%
print("coefficients:",model.coef_)
# Out:
# coefficients: [-2.27802244e+03 -6.35536071e+02  3.14404687e+02  3.54509019e+02
#   8.35614688e+01 -4.49628878e+01 -5.74712945e+01 -2.84217094e-14
#  10223.69002441 10071.19370931  7098.22654281 10443.19010895
#   7941.15357414  9884.6043075   6905.57538072 12044.34886628
#   8128.16715831 11206.73399571 13697.15641875 11233.87176762
#  17082.11018321  6666.14832995 16110.92094521  7412.21771198
#  12949.99326332  7324.24509147 13051.3900314   8623.34805086
#  26269.71810489  7714.26926242  9490.0423049   8431.41188061
#  13082.83673475 13470.11646508  8454.3933114   9555.10895626
#  12514.0171286  18999.54826404 13656.56810433  9572.24206412
#  18419.36858208 10418.5590901   9561.94038521  9771.53029667
#   9945.71411741  9599.25245228  9219.41852255  8448.36682639
#   7966.61934535  8095.96674975 10504.73459916 12176.97842035
#   6608.75678291  7682.16242843 12933.60651151  9851.66269651
#  14042.36347335  8353.10241748  6365.4695177   9449.3809541
#   8117.81674246  7273.21748312 13059.27333508  4747.13295256
#   8829.67509567  8741.34828064 12983.85649823 15642.65362311
#   9149.45759873 12978.91435524  8135.93177748  7283.27342681
#   6398.86753014  7755.62162327  7169.24040403 12966.74900547
#  21443.47216587 11078.18470392  7274.57645999 19278.77524754
#   8129.802444   14163.14718758  6491.28123485] 753      9950
# 858      7995
# 630      7500
# 1412     9950
# 975      8950
#         ...
# 1113     5750
# 175     19950
# 1428     8450
# 298     13995
# 1126     6800
# Name: Price, Length: 287, dtype: int64

# %%
residual=y_test-y_pred
residual
# Out:
# 753     -746.898512
# 858    -2329.626163
# 630    -1487.285027
# 1412     516.459119
# 975      303.133674
#            ...
# 1113   -1524.576460
# 175      671.224752
# 1428     320.197556
# 298     -168.147188
# 1126     308.718765
# Name: Price, Length: 287, dtype: float64

# %%
sns.displot(residual,kind='kde')

# %%
plt.scatter(y_test,y_pred)
plt.plot(y_test,y_pred)

# %% [markdown]
# Evaluation metrics;

# %% [markdown]
# 5.Apply Lasso and Ridge methods on the model.

# %%
# Lasso Regression
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(x_train, y_train)
lasso_pred = lasso_model.predict(x_test)
lasso_mse = mean_squared_error(y_test, lasso_pred)

# Ridge Regression
ridge_model = Ridge(alpha=0.1)  
ridge_model.fit(x_train, y_train)
ridge_pred = ridge_model.predict(x_test)
ridge_mse = mean_squared_error(y_test, ridge_pred)

print("Lasso MSE:", lasso_mse)
print("Ridge MSE:", ridge_mse)
# Out:
# Lasso MSE: 1930185.5762768323
# Ridge MSE: 1930281.7134448148

# %% [markdown]
# Graph Visualization

# %% [markdown]
# Interview Questions:

# %% [markdown]
# 1.What is Normalization & Standardization and how is it helpful?
# Ans;Normalization in data-science refers to the process of scalling numeric features to a common range,typically between 0 and 1.
# The goal of normalization is to bring all the features into a similer scale,which is perticularly important for algorithms that are sensitive to the scale of the features
#
# Standardization in data-science refers to the process of transforming data in such a way that it has mean of 0 and standard deviation of 1.
# This process is also known as z-score normalization

# %% [markdown]
# 2.What techniques can be used to address multicollinearity in multiple linear regression?
# Ans; Multicollinearity occurs when independent variables in a regression model are highly correlated with each other.
# This can cause issues in multiple linear regression, such as unstable coefficients estimates and difficulties in interpreting the importance of individual predictors.
